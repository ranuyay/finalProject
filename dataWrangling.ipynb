# %%
import pandas as pd

# %%
individual2016 = pd.read_csv("Data/individual2016.csv")

# %%
individual2016
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0        1      NaN         1    1    2.0      NaN     2.0     NaN      2.0
# 1        2      NaN         1    2    2.0      NaN     2.0     NaN      1.0
# 2        1      NaN         1    2    2.0      NaN     NaN     NaN      NaN
# 3        1      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4        1      NaN         1    2    2.0      NaN     NaN     NaN      NaN
# ...    ...      ...       ...  ...    ...      ...     ...     ...      ...
# 97164    1      NaN         4    1    NaN      NaN     NaN     NaN      NaN
# 97165    2      NaN         4    1    2.0      3.0     NaN     NaN      NaN
# 97166    3      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 97167    1      NaN         4    1    2.0      2.0     NaN     NaN      NaN
# 97168    2      NaN         4    2    2.0      1.0     NaN     NaN      NaN
#
# ...
